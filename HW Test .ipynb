# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import sys
# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 646

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Black River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=black river
# Processing Record 2 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=muros
# Processing Record 3 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bethel
# Processing Record 4 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=vaini
# Processing Record 5 | Pimentel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=pimentel
# Processing Record 6 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=katsuura
# Processing Record 7 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=severo-kurilsk
# Processing Record 8 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=fukue
# Processing Record 9 | Tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tomatlan
# Processing Record 10 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=egvekinot
# Processing Record 11 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=vao
# Processing Record 12 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=aykhal
# Processing Record 13 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=puerto ayora
# Processing Record 14 | Gummidipundi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=gummidipundi
# Processing Record 15 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=chicama
# Processing Record 16 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=punta arenas
# Processing Record 17 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=srednekolymsk
# Processing Record 18 | San Jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=san jose
# Processing Record 19 | Corrales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=corrales
# Processing Record 20 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=upernavik
# Processing Record 21 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=constitucion
# Processing Record 22 | Nichinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nichinan
# Processing Record 23 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=salalah
# Processing Record 24 | Rajapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=rajapur
# Processing Record 25 | Isetskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=isetskoye
# Processing Record 26 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=rikitea
# Processing Record 27 | Hillsborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hillsborough
# Processing Record 28 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=esperance
# City not found. Skipping...
# Processing Record 29 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tuktoyaktuk
# Processing Record 30 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=qaanaaq
# Processing Record 31 | Smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=smithers
# Processing Record 32 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tuatapere
# Processing Record 33 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=yellowknife
# Processing Record 34 | Trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=trinidad
# Processing Record 35 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=airai
# Processing Record 36 | Lavumisa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lavumisa
# Processing Record 37 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=mataura
# Processing Record 38 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=thompson
# Processing Record 39 | Minyar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=minyar
# Processing Record 40 | Letka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=letka
# Processing Record 41 | Aqtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=aqtobe
# Processing Record 42 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=san cristobal
# Processing Record 43 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hilo
# Processing Record 44 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=salinopolis
# Processing Record 45 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ribeira grande
# Processing Record 46 | Yendi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=yendi
# Processing Record 47 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=saskylakh
# City not found. Skipping...
# Processing Record 48 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=torbay
# City not found. Skipping...
# Processing Record 49 | Port Hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port hawkesbury
# Processing Record 50 | Anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=anloga
# Processing Record 51 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=avarua
# Processing Record 52 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=pisco
# Processing Record 53 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nikolskoye
# Processing Record 54 | Merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=merauke
# City not found. Skipping...
# Processing Record 55 | Umm Kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=umm kaddadah
# Processing Record 56 | Vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=vrangel
# Processing Record 57 | Usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=usinsk
# Processing Record 58 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=cape town
# Processing Record 59 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=busselton
# Processing Record 60 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=talnakh
# Processing Record 61 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=mahebourg
# Processing Record 62 | Cubuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=cubuk
# Processing Record 63 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=carnarvon
# Processing Record 64 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=codrington
# Processing Record 65 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lata
# Processing Record 66 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=namibe
# Processing Record 67 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=qaqortoq
# Processing Record 68 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port lincoln
# City not found. Skipping...
# Processing Record 69 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port alfred
# Processing Record 70 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=albany
# Processing Record 71 | Biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=biltine
# Processing Record 72 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port elizabeth
# City not found. Skipping...
# Processing Record 73 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sitka
# Processing Record 74 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=cidreira
# Processing Record 75 | Zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=zhezkazgan
# Processing Record 76 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=atuona
# Processing Record 77 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nanortalik
# Processing Record 78 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=saint george
# Processing Record 79 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port-gentil
# Processing Record 80 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hithadhoo
# City not found. Skipping...
# Processing Record 81 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=gamba
# Processing Record 82 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=leningradskiy
# Processing Record 83 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tasiilaq
# Processing Record 84 | Adre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=adre
# Processing Record 85 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tiksi
# Processing Record 86 | Duverge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=duverge
# Processing Record 87 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=chokurdakh
# Processing Record 88 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=georgetown
# Processing Record 89 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kaitangata
# City not found. Skipping...
# Processing Record 90 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=vardo
# Processing Record 91 | Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=leh
# Processing Record 92 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=east london
# Processing Record 93 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bredasdorp
# Processing Record 94 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=arraial do cabo
# Processing Record 95 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=berlevag
# Processing Record 96 | Punta Cardon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=punta cardon
# Processing Record 97 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hermanus
# Processing Record 98 | Oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=oktyabrskoye
# Processing Record 99 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bathsheba
# Processing Record 100 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lompoc
# Processing Record 101 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=saldanha
# Processing Record 102 | Marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=marrakesh
# Processing Record 103 | Puro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=puro
# Processing Record 104 | Moses Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=moses lake
# Processing Record 105 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=longyearbyen
# Processing Record 106 | Ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ossora
# Processing Record 107 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=paamiut
# Processing Record 108 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hamilton
# Processing Record 109 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kavieng
# Processing Record 110 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=dikson
# Processing Record 111 | Mastic Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=mastic beach
# Processing Record 112 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kiunga
# Processing Record 113 | Kedgwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kedgwick
# Processing Record 114 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=dingle
# City not found. Skipping...
# Processing Record 115 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lorengau
# Processing Record 116 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=marawi
# Processing Record 117 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kavaratti
# Processing Record 118 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=los llanos de aridane
# Processing Record 119 | Lucea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lucea
# Processing Record 120 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=rio grande
# Processing Record 121 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=khatanga
# Processing Record 122 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=aklavik
# Processing Record 123 | Yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=yatou
# Processing Record 124 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=cockburn town
# Processing Record 125 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=barrow
# Processing Record 126 | Liverpool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=liverpool
# Processing Record 127 | Trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=trairi
# Processing Record 128 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ushuaia
# Processing Record 129 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hobart
# Processing Record 130 | Lazurne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lazurne
# City not found. Skipping...
# Processing Record 131 | Kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kenora
# Processing Record 132 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bluff
# Processing Record 133 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tautira
# Processing Record 134 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kapaa
# Processing Record 135 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=mar del plata
# Processing Record 136 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bilma
# Processing Record 137 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=pacific grove
# Processing Record 138 | Tunduma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tunduma
# Processing Record 139 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=seoul
# Processing Record 140 | Mumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=mumford
# Processing Record 141 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sioux lookout
# Processing Record 142 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=shingu
# Processing Record 143 | Racine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=racine
# Processing Record 144 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kenai
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 145 | Marsh Harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=marsh harbour
# Processing Record 146 | Sovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sovetskiy
# Processing Record 147 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=butaritari
# Processing Record 148 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=soyo
# Processing Record 149 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=vila velha
# Processing Record 150 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sechura
# Processing Record 151 | Santa Barbara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=santa barbara
# City not found. Skipping...
# Processing Record 152 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=narsaq
# City not found. Skipping...
# Processing Record 153 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=victoria
# Processing Record 154 | Jacinto City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=jacinto city
# Processing Record 155 | Veseloyarsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=veseloyarsk
# Processing Record 156 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=isangel
# Processing Record 157 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=vostok
# Processing Record 158 | Sile
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sile
# Processing Record 159 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kodiak
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 160 | Kizukuri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kizukuri
# Processing Record 161 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=touros
# Processing Record 162 | San Rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=san rafael
# Processing Record 163 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=quatre cocos
# Processing Record 164 | Oeiras do Para
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=oeiras do para
# City not found. Skipping...
# Processing Record 165 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=shimoda
# Processing Record 166 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=pevek
# Processing Record 167 | Gurjaani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=gurjaani
# Processing Record 168 | Yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=yanam
# Processing Record 169 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port hardy
# Processing Record 170 | Zyryanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=zyryanovsk
# Processing Record 171 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ponta do sol
# Processing Record 172 | Karasuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=karasuk
# Processing Record 173 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=vila franca do campo
# Processing Record 174 | Nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nalut
# Processing Record 175 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=meulaboh
# Processing Record 176 | Jesup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=jesup
# Processing Record 177 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=new norfolk
# Processing Record 178 | Nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nago
# City not found. Skipping...
# Processing Record 179 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=manokwari
# Processing Record 180 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=marzuq
# Processing Record 181 | Batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=batagay
# Processing Record 182 | Dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=dudinka
# Processing Record 183 | Los Corrales de Buelna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=los corrales de buelna
# Processing Record 184 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=jamestown
# Processing Record 185 | Liuzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=liuzhou
# Processing Record 186 | Rivers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=rivers
# Processing Record 187 | Rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=rundu
# Processing Record 188 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=cabo san lucas
# Processing Record 189 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=noumea
# Processing Record 190 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=vanimo
# Processing Record 191 | Nikki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nikki
# City not found. Skipping...
# Processing Record 192 | Amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=amapa
# Processing Record 193 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=geraldton
# City not found. Skipping...
# Processing Record 194 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=provideniya
# Processing Record 195 | Kandrian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kandrian
# Processing Record 196 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=alta floresta
# Processing Record 197 | Tucuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tucuman
# Processing Record 198 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=clyde river
# Processing Record 199 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hambantota
# Processing Record 200 | Hanzhong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hanzhong
# Processing Record 201 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lebu
# Processing Record 202 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port macquarie
# Processing Record 203 | Rumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=rumford
# Processing Record 204 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=goderich
# Processing Record 205 | Bukachacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bukachacha
# Processing Record 206 | Sarangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sarangani
# Processing Record 207 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=yar-sale
# Processing Record 208 | Marsabit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=marsabit
# Processing Record 209 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=yulara
# Processing Record 210 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=san quintin
# Processing Record 211 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=araouane
# Processing Record 212 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ulladulla
# Processing Record 213 | Dongobesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=dongobesh
# Processing Record 214 | Snyder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=snyder
# City not found. Skipping...
# Processing Record 215 | Jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=jumla
# Processing Record 216 | Oyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=oyama
# City not found. Skipping...
# Processing Record 217 | Veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=veraval
# Processing Record 218 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=belaya gora
# City not found. Skipping...
# Processing Record 219 | Malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=malanje
# Processing Record 220 | Valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=valparaiso
# Processing Record 221 | Puerto Narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=puerto narino
# Processing Record 222 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=coquimbo
# City not found. Skipping...
# Processing Record 223 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=champerico
# Processing Record 224 | Bangkalan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bangkalan
# Processing Record 225 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=havre-saint-pierre
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 226 | Den Helder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=den helder
# Processing Record 227 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nemuro
# Processing Record 228 | Trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=trincomalee
# Processing Record 229 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=maragogi
# Processing Record 230 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=roma
# Processing Record 231 | Pangoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=pangoa
# Processing Record 232 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=husavik
# Processing Record 233 | Jasper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=jasper
# Processing Record 234 | Aguazul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=aguazul
# Processing Record 235 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sisimiut
# Processing Record 236 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=cherskiy
# Processing Record 237 | Rapid City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=rapid city
# Processing Record 238 | Boralday
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=boralday
# Processing Record 239 | Santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=santiago
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 240 | Juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=juneau
# Processing Record 241 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=coihaique
# Processing Record 242 | Peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=peniche
# Processing Record 243 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hami
# Processing Record 244 | Oum Hadjer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=oum hadjer
# Processing Record 245 | Ibaiti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ibaiti
# Processing Record 246 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=saint-augustin
# Processing Record 247 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tilichiki
# Processing Record 248 | Tipuani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tipuani
# City not found. Skipping...
# Processing Record 249 | Moscow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=moscow
# Processing Record 250 | Kot Addu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kot addu
# Processing Record 251 | Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kurilsk
# Processing Record 252 | Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nhulunbuy
# Processing Record 253 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kloulklubed
# Processing Record 254 | Vigrestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=vigrestad
# Processing Record 255 | Hibbing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hibbing
# Processing Record 256 | Innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=innisfail
# Processing Record 257 | Poole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=poole
# Processing Record 258 | Aleppo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=aleppo
# Processing Record 259 | Kondinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kondinskoye
# City not found. Skipping...
# Processing Record 260 | Salamiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=salamiyah
# Processing Record 261 | San Policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=san policarpo
# Processing Record 262 | Port Keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port keats
# Processing Record 263 | Ereymentau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ereymentau
# Processing Record 264 | Rize
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=rize
# City not found. Skipping...
# Processing Record 265 | Ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ishigaki
# Processing Record 266 | Baltay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=baltay
# Processing Record 267 | Callaway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=callaway
# Processing Record 268 | Spydeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=spydeberg
# Processing Record 269 | Dhing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=dhing
# Processing Record 270 | Temiscaming
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=temiscaming
# Processing Record 271 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=chapais
# Processing Record 272 | Cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=cururupu
# Processing Record 273 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=souillac
# City not found. Skipping...
# Processing Record 274 | Puerto Carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=puerto carreno
# Processing Record 275 | Ban Nahin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ban nahin
# City not found. Skipping...
# Processing Record 276 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port blair
# Processing Record 277 | Tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tsiroanomandidy
# Processing Record 278 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=deputatskiy
# Processing Record 279 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=saint-philippe
# Processing Record 280 | Shirokiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=shirokiy
# Processing Record 281 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ancud
# Processing Record 282 | San Francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=san francisco
# City not found. Skipping...
# Processing Record 283 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=inhambane
# Processing Record 284 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=guerrero negro
# Processing Record 285 | Mafra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=mafra
# City not found. Skipping...
# Processing Record 286 | Saint-Georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=saint-georges
# Processing Record 287 | Wamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=wamba
# Processing Record 288 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=norman wells
# City not found. Skipping...
# Processing Record 289 | Suluq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=suluq
# Processing Record 290 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=portland
# Processing Record 291 | Shitanjing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=shitanjing
# Processing Record 292 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=san patricio
# Processing Record 293 | Kralendijk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kralendijk
# Processing Record 294 | Port Hueneme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=port hueneme
# Processing Record 295 | Nador
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nador
# Processing Record 296 | Tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tabou
# Processing Record 297 | Etchoropo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=etchoropo
# Processing Record 298 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=faya
# Processing Record 299 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=auki
# Processing Record 300 | Doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=doha
# Processing Record 301 | Havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=havelock
# Processing Record 302 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=flinders
# Processing Record 303 | Prince George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=prince george
# Processing Record 304 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kununurra
# Processing Record 305 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=atambua
# Processing Record 306 | Udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=udachnyy
# Processing Record 307 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=yerbogachen
# Processing Record 308 | Huron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=huron
# City not found. Skipping...
# Processing Record 309 | Tynda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tynda
# Processing Record 310 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=grindavik
# City not found. Skipping...
# Processing Record 311 | Kathu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kathu
# Processing Record 312 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=coahuayana
# Processing Record 313 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=viedma
# Processing Record 314 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=karratha
# Processing Record 315 | Traralgon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=traralgon
# City not found. Skipping...
# Processing Record 316 | Livramento
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=livramento
# Processing Record 317 | Bengbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bengbu
# Processing Record 318 | Sangmelima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sangmelima
# Processing Record 319 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hofn
# Processing Record 320 | Lamas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lamas
# Processing Record 321 | Dunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=dunda
# City not found. Skipping...
# Processing Record 322 | Inirida
# ...
# Processing Record 445 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=alice springs
# Processing Record 446 | Berkovica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=berkovica
# Processing Record 447 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lagoa
# Processing Record 448 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bambous virieux
# Processing Record 449 | Dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=dukat
# Processing Record 450 | Teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=teya
# Processing Record 451 | Arinos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=arinos
# Processing Record 452 | Presidencia Roque Saenz Pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=presidencia roque saenz pena
# Processing Record 453 | Sedam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sedam
# Processing Record 454 | Hakkari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hakkari
# Processing Record 455 | Fairlie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=fairlie
# Processing Record 456 | Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=coolum beach
# Processing Record 457 | Daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=daru
# Processing Record 458 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=aksarka
# Processing Record 459 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lasa
# Processing Record 460 | Saraland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=saraland
# Processing Record 461 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kudahuvadhoo
# City not found. Skipping...
# Processing Record 462 | Honjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=honjo
# Processing Record 463 | Sunrise Manor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sunrise manor
# City not found. Skipping...
# Processing Record 464 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=walvis bay
# Processing Record 465 | Kaitong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kaitong
# Processing Record 466 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tura
# Processing Record 467 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=naze
# Processing Record 468 | Buenos Aires
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=buenos aires
# Processing Record 469 | Kondagaon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kondagaon
# City not found. Skipping...
# Processing Record 470 | Puerto del Rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=puerto del rosario
# Processing Record 471 | Biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=biak
# Processing Record 472 | Matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=matagami
# Processing Record 473 | Sal Rei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sal rei
# Processing Record 474 | Tongchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tongchuan
# Processing Record 475 | Barahona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=barahona
# Processing Record 476 | Nizhnevartovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nizhnevartovsk
# Processing Record 477 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hasaki
# Processing Record 478 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kieta
# Processing Record 479 | Kilindoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kilindoni
# Processing Record 480 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=alyangula
# Processing Record 481 | Tumpat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tumpat
# Processing Record 482 | Marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=marienburg
# Processing Record 483 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=huarmey
# Processing Record 484 | Maracaibo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=maracaibo
# Processing Record 485 | Yeniseysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=yeniseysk
# Processing Record 486 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=zhigansk
# Processing Record 487 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ilulissat
# Processing Record 488 | Tiangua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tiangua
# Processing Record 489 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=saint anthony
# Processing Record 490 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ayan
# Processing Record 491 | Salta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=salta
# Processing Record 492 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sept-iles
# Processing Record 493 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=komsomolskiy
# Processing Record 494 | The Pas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=the pas
# Processing Record 495 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nishihara
# Processing Record 496 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=avera
# Processing Record 497 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=pangnirtung
# City not found. Skipping...
# Processing Record 498 | Lerwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lerwick
# Processing Record 499 | Sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sterling
# Processing Record 500 | Bella Union
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bella union
# Processing Record 501 | Tabory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tabory
# Processing Record 502 | Ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ucluelet
# Processing Record 503 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=fort nelson
# Processing Record 504 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=beloha
# Processing Record 505 | Hrodna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hrodna
# City not found. Skipping...
# Processing Record 506 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=luganville
# Processing Record 507 | Panguipulli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=panguipulli
# City not found. Skipping...
# Processing Record 508 | Soldotna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=soldotna
# Processing Record 509 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bonthe
# Processing Record 510 | Tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=tezu
# City not found. Skipping...
# Processing Record 511 | Uvinza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=uvinza
# Processing Record 512 | Nantong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nantong
# Processing Record 513 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hovd
# Processing Record 514 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=camacha
# Processing Record 515 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=nelson bay
# Processing Record 516 | Awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=awbari
# Processing Record 517 | Balotra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=balotra
# Processing Record 518 | Le Port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=le port
# Processing Record 519 | Kuruman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=kuruman
# Processing Record 520 | Burley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=burley
# Processing Record 521 | Omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=omboue
# Processing Record 522 | Valle de Allende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=valle de allende
# Processing Record 523 | Sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=sorong
# City not found. Skipping...
# Processing Record 524 | Priladozhskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=priladozhskiy
# Processing Record 525 | Garissa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=garissa
# Processing Record 526 | Lydenburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=lydenburg
# City not found. Skipping...
# Processing Record 527 | Bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=bowen
# Processing Record 528 | Elwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=elwood
# Processing Record 529 | Valentin Gomez Farias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=valentin gomez farias
# Processing Record 530 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=taoudenni
# Processing Record 531 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=namatanai
# Processing Record 532 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=makakilo city
# Processing Record 533 | Maracas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=maracas
# Processing Record 534 | Torbat-e Jam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=torbat-e jam
# Processing Record 535 | Storforshei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=storforshei
# Processing Record 536 | Wadi Musa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=wadi musa
# Processing Record 537 | Hollins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=hollins
# Processing Record 538 | Santa Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=santa cruz
# Processing Record 539 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ostrovnoy
# Processing Record 540 | Ilovlya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=ilovlya
# Processing Record 541 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=caravelas
# City not found. Skipping...
# Processing Record 542 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=haines junction
# Processing Record 543 | Mount Darwin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=mount darwin
# Processing Record 544 | Pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=pangai
# Processing Record 545 | Outjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=outjo
# Processing Record 546 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=luanda
# Processing Record 547 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=comodoro rivadavia
# City not found. Skipping...
# Processing Record 548 | Dole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=dole
# Processing Record 549 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=north bend
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 550 | Khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=khani
# Processing Record 551 | Rushden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=09f3a63324b51924811d57558fb9660c&q=rushden

# %%
#Create Dictionary 
weather_dict = {"City" : city_name,
               "Cloudiness" : cloudiness,
               "Country" : country,
               "Date" : date,
               "Humidity" : humidity,
               "Lat" : lat,
               "Lng" : lng,
                "Max temp" : max_temp,
               "Wind Speed" : wind_speed}

weather_df = pd.DataFrame(weather_dict)
weather_df.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max temp      551
# Wind Speed    551
# dtype: int64

# %%
weather_df.to_csv("Output/weather_data.csv")
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Black River          20      JM  1564016043        79  18.03  -77.85
# 1        Muros          40      ES  1564016044        93  42.77   -9.06
# 2       Bethel          90      US  1564016046       100  60.79 -161.76
# 3        Vaini          75      IN  1564016047        94  15.34   74.49
# 4     Pimentel          22      BR  1564016048        86  -3.70  -45.50
#
#    Max temp  Wind Speed
# 0     84.20       11.41
# 1     71.01       11.41
# 2     60.80       12.75
# 3     71.60        9.17
# 4     73.91        2.06

# %%
#Latitude vs Temp scatter plot
plt.scatter(weather_df["Lat"], weather_df["Max temp"], marker = "o", s=10)
plt.title("City Latitude vs. Max Temperature (7/24/2019)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitute")
plt.grid()
plt.show()

# %%
#Latitude vs Humidity scatterplot 
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker = "o", s=10)
plt.title("City Latitude vs. Humidity (7/24/2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitute")
plt.grid()
plt.ylim(0, 100)
plt.show()

# %%
#Latitude vs Cloudiness ScatterPlot 
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker = "o", s=10)
plt.title("City Latitude vs. Cloudiness (7/24/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitute")
plt.ylim(0, 100)
plt.grid()
plt.show()

# %%
#Latitude vs Windspeed 
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker = "o", s=10)
plt.title("City Latitude vs. Wind Speed (7/24/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitute")
plt.ylim(0,30)
plt.grid()
plt.show()
